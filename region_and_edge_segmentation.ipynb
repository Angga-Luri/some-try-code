# %% [markdown]
# <a href="https://colab.research.google.com/github/Angga-Luri/some-try-code/blob/main/region_and_edge_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import canny
from skimage import data,morphology
from skimage.color import rgb2gray
import scipy.ndimage as nd
import cv2 
from google.colab.patches import cv2_imshow
plt.rcParams["figure.figsize"] = (12,8)
# %matplotlib inline

# %%
rambu = cv2.imread('rambu_lalin.jpg')

# %%
cv2_imshow(rambu)
# Out:
# <PIL.Image.Image image mode=RGB size=928x500 at 0x7FDC4D5FDD90>

# %%
rambu_gray = cv2.cvtColor(rambu, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(rambu_gray)
# Out:
# <PIL.Image.Image image mode=L size=928x500 at 0x7FDC1B622D90>

# %%
edges = canny(rambu_gray)
plt.imshow(edges, interpolation='gaussian')
plt.title('Canny detector')
# Out:
# Text(0.5, 1.0, 'Canny detector')

# %%
fill_im = nd.binary_fill_holes(edges)
plt.imshow(fill_im)
plt.title('Region Filling')
# Out:
# Text(0.5, 1.0, 'Region Filling')

# %%
from skimage.filters import sobel
elevation_map = sobel(rambu_gray)
fig, ax = plt.subplots(figsize=(4, 3))
plt.imshow(elevation_map, cmap=plt.cm.gray, interpolation='nearest')
plt.axis('on')
ax.set_title('elevation_map')
# Out:
# Text(0.5, 1.0, 'elevation_map')
