# %% [markdown]
# <a href="https://colab.research.google.com/github/Angga-Luri/some-try-code/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install opencv-python
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab.patches import cv2_imshow  
img2 = cv2.imread('tomat.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img2)
img = cv2.cvtColor(np.array(img2),cv2.COLOR_BGR2GRAY);
# Out:
# <PIL.Image.Image image mode=RGB size=360x240 at 0x7F55B5DEC6D0>

# %%
ret, bw_img = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

# %%
bw = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

# %%
from google.colab.patches import cv2_imshow  
cv2_imshow(bw_img)
# Out:
# <PIL.Image.Image image mode=L size=360x240 at 0x7F55B5DECCA0>
