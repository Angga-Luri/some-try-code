# %% [markdown]
# <a href="https://colab.research.google.com/github/Angga-Luri/some-try-code/blob/main/preprocessing_vehicle_imge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing libraries
import cv2
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from PIL import Image
import os, sys
# Reading the image
image = cv2.imread("car.jpg")
print("Shape:", image.shape)
# cv2_imshow(image)
# Scaling Up the image 1.8 and 1.4 times at x and y axis respectively by specifying both scaling factors
up_x = 1.8
up_y = 1.4
# Scaling Down the image 0.2 times specifying a single scale factor
down = 0.2
scaled_down = cv2.resize(image, None, fx=down, fy=down, interpolation=cv2.INTER_LINEAR)
# imResize = image.resize((500,500), Image.ANTIALIAS)
# image_scaled_up = cv2.resize(image, None, fx= up_x, fy= up_y, interpolation=cv2.INTER_LINEAR)
# Display images and press any key to check next image
print("Scaled Down\n")
# print(scaled_down)
cv2_imshow(scaled_down)
cv2.waitKey()
# print("\nScaled Up\n")
# print(image_scaled_up)
# cv2_imshow(image_scaled_up)
# cv2.waitKey()
up_width = 1000
up_height = 400
up_points = (up_width, up_height)
resized_up = cv2.resize(image, up_points, interpolation= cv2.INTER_LINEAR)
cv2_imshow(resized_up)
# Out:
# Shape: (394, 749, 3)
# Scaled Down
# <PIL.Image.Image image mode=RGB size=150x79 at 0x7F8CD01E3220>
# <PIL.Image.Image image mode=RGB size=1000x400 at 0x7F8CD01E06D0>

# %%
# Out:
# Resized Down by defining height and width
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F11C115F6A0>
# Resized Up by defining height and width
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F11C115DC30>

# %%
# patch = (120, 120)
# center = (128, 64)
# cropped_image = cv2.getRectSubPix(resize_down, patch, center)
# cv2_imshow(cropped_image)
# img = cv2.imread('car.jpg')
start_row, start_col = int(180), int (1)
end_row, end_col = int(500), int (800)
image_cropped = image_scaled_up[start_row:end_row, start_col:end_col]
cv2_imshow(image_cropped)
# Out:
# <PIL.Image.Image image mode=RGB size=799x152 at 0x7F11C121F4F0>

# %%
img_gray = cv2.cvtColor(image_cropped, cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=799x152 at 0x7F11C115DBD0>

# %%
# ret, thresh1 = cv2.threshold(img_gray, 200, 255, cv2.THRESH_BINARY)
# ret, thresh2 = cv2.threshold(img_gray, 200, 255, cv2.THRESH_BINARY_INV)
# ret, thresh3 = cv2.threshold(img_gray, 200, 255, cv2.THRESH_TRUNC)
# ret, thresh4 = cv2.threshold(img_gray, 120, 255, cv2.THRESH_TOZERO)
ret, image_thresh5 = cv2.threshold(img_gray, 100, 255, cv2.THRESH_TOZERO_INV)

# the window showing output images
# with the corresponding thresholding
# techniques applied to the input images
# cv2_imshow(img_gray)
# cv2_imshow(thresh1)
# cv2_imshow(thresh2)
# cv2_imshow(thresh3)
# cv2_imshow(thresh4)
cv2_imshow(image_thresh5)
# Out:
# <PIL.Image.Image image mode=L size=799x152 at 0x7F11C115DD80>

# %%
# Set rows and columns
# Downsize the image using new  width and height
down_width = 64
down_height = 64
down_points = (down_width, down_height)
resize_down = cv2.resize(image_thresh5, down_points, interpolation= cv2.INTER_LINEAR)
# Downsize the image using new  width and height
# up_width = 128
# up_height = 128
# up_points = (up_width, up_height)
# resize_up = cv2.resize(image_thresh5, up_points, interpolation = cv2.INTER_LINEAR)
# Display images
print("Resized Down by defining height and width\n")
cv2_imshow(resize_down)
cv2.waitKey()
# print("\nResized Up by defining height and width\n")
# cv2_imshow(resize_up)
# cv2.waitKey()
# cv2.destroyAllWindows()
# Out:
# Resized Down by defining height and width
# <PIL.Image.Image image mode=L size=64x64 at 0x7F1200B3F7F0>
# -1

# %%
from PIL import Image
from numpy import *
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib
import os

# %%
img_rows, img_cols = 124, 124

# number of channels
img_channels = 1

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# cd '/content/gdrive/My Drive/riset/dataset/try_dataset'
cd '/content/gdrive/My Drive/riset/dataset/type1'
# Out:
#   File "<ipython-input-25-5c4c4e67d70e>", line 1
#     cd '/content/gdrive/My Drive/riset/dataset/try_dataset'
#        ^
# SyntaxError: invalid syntax

# %%
#  path1 = '/content/gdrive/My Drive/riset/dataset/type1'
#  path2 = '/content/gdrive/My Drive/riset/dataset_preprocessing/type1'

# path_dataset_type1 = '/content/gdrive/My Drive/riset/dataset/type1'
# path_dataset_preprocessing_type1 = '/content/gdrive/My Drive/riset/dataset_preprocessing/type1'

# path_dataset_type2 = '/content/gdrive/My Drive/riset/dataset/type2'
# path_dataset_preprocessing_type2 = '/content/gdrive/My Drive/riset/dataset_preprocessing/type2'

# path_dataset_type3 = '/content/gdrive/My Drive/riset/dataset/type3'
# path_dataset_preprocessing_type3 = '/content/gdrive/My Drive/riset/dataset_preprocessing/type3'

# path_dataset_type4 = '/content/gdrive/My Drive/riset/dataset/type4'
# path_dataset_preprocessing_type4 = '/content/gdrive/My Drive/riset/dataset_preprocessing/type4'

path_dataset_type5 = '/content/gdrive/My Drive/riset/dataset/type5'
path_dataset_preprocessing_type5 = '/content/gdrive/My Drive/riset/dataset_preprocessing/type5'

# path_dataset_try = '/content/gdrive/My Drive/riset/try_dataset'
# path_dataset_try_dataset_pre = '/content/gdrive/My Drive/riset/try_dataset_pre'

# %%
# listing1 = os.listdir(path_dataset_type1)
# num_samples1=size(listing1)
# print(listing1)
# print(num_samples1)

# listing2 = os.listdir(path_dataset_type2)
# num_samples2=size(listing2)
# print(listing2)
# print(num_samples2)

# listing3 = os.listdir(path_dataset_type3)
# num_samples3=size(listing3)
# print(listing3)
# print(num_samples3)

# listing4 = os.listdir(path_dataset_type4)
# num_samples4=size(listing4)
# print(listing4)
# print(num_samples4)

listing5 = os.listdir(path_dataset_type5)
num_samples5=size(listing5)
print(listing5)
print(num_samples5)

# listing_try = os.listdir(path_dataset_try)
# num_samples_try=size(listing_try)
# print(listing_try)
# print(num_samples_try)
# Out:
# ['5 (435).png', '5 (436).png', '5 (437).png', '5 (438).png', '5 (439).png', '5 (440).png', '5 (441).png', '5 (442).png', '5 (443).png', '5 (444).png', '5 (445).png', '5 (446).png', '5 (447).png', '5 (448).png', '5 (449).png', '5 (450).png', '5 (451).png', '5 (452).png', '5 (453).png', '5 (454).png', '5 (496).png', '5 (497).png', '5 (498).png', '5 (499).png', '5 (500).png', '5 (501).png', '5 (502).png', '5 (503).png', '5 (511).png', '5 (512).png', '5 (513).png', '5 (514).png', '5 (515).png', '5 (516).png', '5 (517).png', '5 (518).png', '5 (519).png', '5 (520).png', '5 (521).png', '5 (522).png', '5 (523).png', '5 (524).png', '5 (525).png', '5 (526).png', '5 (527).png', '5 (528).png', '5 (529).png', '5 (530).png', '5 (531).png', '5 (532).png', '5 (533).png', '5 (534).png', '5 (535).png', '5 (547).png', '5 (548).png', '5 (549).png', '5 (550).png', '5 (476).png', '5 (477).png', '5 (478).png', '5 (479).png', '5 (480).png', '5 (481).png', '5 (482).png', '5 (483).png', '5 (484).png', '5 (485
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
from google.colab.patches import cv2_imshow


start_row, start_col = int(180), int (1)
end_row, end_col = int(500), int (800)
up_width = 800
up_height = 300
up_points = (up_width, up_height)
resize = (64, 64)
# listingStr = len(listing1)
# listingInt = int(str(listingInt))
# print (str(listingInt))

for file in listing5:
    image = cv2.imread(path_dataset_type5+ '/' + file)
    # im = Image.open( path_dataset_try+ '/' + file)
    image_scaled_up = cv2.resize(image, up_points, interpolation=cv2.INTER_LINEAR)
    image_cropped = image_scaled_up[start_row:end_row, start_col:end_col]
    img_gray = cv2.cvtColor(image_cropped, cv2.COLOR_BGR2GRAY)
    ret, image_thresh5 = cv2.threshold(img_gray, 100, 255, cv2.THRESH_TOZERO_INV)
    image_resize = cv2.resize(image_thresh5, resize, interpolation=cv2.INTER_LINEAR)
    # img_gray2 = cv2.cvtColor(image_resize, cv2.COLOR_BGR2GRAY)
    cv2_imshow(image_resize)
    # img = im.resize((img_rows,img_cols))
    # gray = img.convert('L')
    # image_resize.save(path_dataset_try_dataset_pre +'/' +  file, "JPEG")
    # cv2.imwrite(path_dataset_try_dataset_pre +'/' +  file, "JPEG")
    isWritten = cv2.imwrite(path_dataset_preprocessing_type5+'/'+file, image_resize)
    if isWritten:
      print('The image is successfully saved.')
    # print(image_resize)
# Out:
# <PIL.Image.Image image mode=L size=64x64 at 0x7FA28DBF3E50>
# The image is successfully saved.
# <PIL.Image.Image image mode=L size=64x64 at 0x7FA28DBF3E50>
# The image is successfully saved.
# <PIL.Image.Image image mode=L size=64x64 at 0x7FA28DBF36A0>
# The image is successfully saved.
# <PIL.Image.Image image mode=L size=64x64 at 0x7FA2C1FDB130>
# The image is successfully saved.
# <PIL.Image.Image image mode=L size=64x64 at 0x7FA2C1FDB130>
# The image is successfully saved.
# <PIL.Image.Image image mode=L size=64x64 at 0x7FA28DBF3E50>
# The image is successfully saved.
# <PIL.Image.Image image mode=L size=64x64 at 0x7FA28DBF3E50>
# The image is successfully saved.
# <PIL.Image.Image image mode=L size=64x64 at 0x7FA2C1FDB130>
# The image is successfully saved.
# <PIL.Image.Image image mode=L size=64x64 at 0x7FA2C1FDB130>
# The image is successfully saved.
# <PIL.Image.Image image mode=L size=64x64 at 0x7FA2C1FDB130>
# The image is successfully saved.
# ...

# %%
listingStr = len(listing1)
listingInt = int(str(listingInt))
print (listingInt)

for file in range(listingInt):
    print (file, listing1[file])
# Out:
# 550
# 0 1 (73).jpg
# 1 1 (74).jpg
# 2 1 (75).jpg
# 3 1 (76).jpg
# 4 N_MOBIL (1).png
# 5 N_MOBIL (2).png
# 6 N_MOBIL (3).png
# 7 N_MOBIL (4).png
# 8 N_MOBIL (5).png
# 9 N_MOBIL (6).png
# 10 N_MOBIL (7).png
# 11 N_MOBIL (8).png
# 12 N_MOBIL (9).png
# 13 N_MOBIL (10).png
# 14 N_MOBIL (11).png
# 15 N_MOBIL (12).png
# 16 N_MOBIL (13).png
# 17 N_MOBIL (14).png
# 18 N_MOBIL (15).png
# 19 N_MOBIL (16).png
# 20 N_MOBIL (17).png
# 21 N_MOBIL (18).png
# 22 N_MOBIL (19).png
# 23 N_MOBIL (20).png
# 24 N_MOBIL (21).png
# 25 N_MOBIL (22).png
# 26 N_MOBIL (23).png
# 27 N_MOBIL (24).png
# 28 N_MOBIL (25).png
# 29 N_MOBIL (26).png
# 30 N_MOBIL (27).png
# 31 N_MOBIL (28).png
# 32 N_MOBIL (29).png
# 33 N_MOBIL (30).png
# 34 N_MOBIL (31).png
# 35 N_MOBIL (32).png
# 36 N_MOBIL (33).png
# 37 N_MOBIL (34).png
# 38 N_MOBIL (35).png
# 39 N_MOBIL (36).png
# 40 N_MOBIL (37).png
# 41 N_MOBIL (38).png
# 42 N_MOBIL (39).png
# 43 N_MOBIL (40).png
# 44 N_MOBIL (41).png
# 45 N_MOBIL (42).png
# 46 N_MOBIL (43).png
# ...
