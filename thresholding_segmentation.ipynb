# %% [markdown]
# <a href="https://colab.research.google.com/github/Angga-Luri/some-try-code/blob/main/thresholding_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
import numpy as np 
from google.colab.patches import cv2_imshow

# %%
rambu = cv2.imread('rambu_lalin.jpg')

# %%
cv2_imshow(rambu)
# Out:
# <PIL.Image.Image image mode=RGB size=928x500 at 0x7FF0C699A040>

# %%
rambu_gray = cv2.cvtColor(rambu, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(rambu_gray)
# Out:
# <PIL.Image.Image image mode=L size=928x500 at 0x7FF0C68808E0>

# %%
ret, thresh1 = cv2.threshold(rambu_gray, 120, 255, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(rambu_gray, 120, 255, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(rambu_gray, 120, 255, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(rambu_gray, 120, 255, cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(rambu_gray, 120, 255, cv2.THRESH_TOZERO_INV)

# %%
cv2_imshow(thresh1)
cv2_imshow(thresh2)
cv2_imshow(thresh3)
cv2_imshow(thresh4)
cv2_imshow(thresh5)
# Out:
# <PIL.Image.Image image mode=L size=928x500 at 0x7FF0C699A0D0>
# <PIL.Image.Image image mode=L size=928x500 at 0x7FF0C699A400>
# <PIL.Image.Image image mode=L size=928x500 at 0x7FF0C699A0D0>
# <PIL.Image.Image image mode=L size=928x500 at 0x7FF0C6A0C2E0>
# <PIL.Image.Image image mode=L size=928x500 at 0x7FF0FD92DD60>
